# %% [markdown]
# <a href="https://colab.research.google.com/github/chamuditha01/DWM-practical/blob/main/dwm1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
b=5
c=a

# %%
a+b
# Out:
# 7

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/insurance_data - insurance_data (2).csv')

# %%
first_100_rows = df.head(10)

# Print all the data in the first 100 rows
print(first_100_rows.to_string())
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children smoker     region    claim
# 0      0          1  39.0   male  23.2             91      Yes         0     No  southeast  1121.87
# 1      1          2  24.0   male  30.1             87       No         0     No  southeast  1131.51
# 2      2          3   NaN   male  33.3             82      Yes         0     No  southeast  1135.94
# 3      3          4   NaN   male  33.7             80       No         0     No  northwest  1136.40
# 4      4          5   NaN   male  34.1            100       No         0     No  northwest  1137.01
# 5      5          6   NaN   male  34.4             96      Yes         0     No  northwest  1137.47
# 6      6          7   NaN   male  37.3             86      Yes         0     No  northwest  1141.45
# 7      7          8  19.0   male  41.1            100       No         0     No  northwest  1146.80
# ...

# %%
df.iloc[0]
# Out:
# index                    0
# PatientID                1
# age                   39.0
# gender                male
# bmi                   23.2
# bloodpressure           91
# diabetic               Yes
# children                 0
# smoker                  No
# region           southeast
# claim              1121.87
# Name: 0, dtype: object

# %%
column_A_firstrow = df['region'].iloc[0]
print(column_A_firstrow)
# Out:
# southeast

# %%
first_100_rows = df.head(10)

# Print all the data in the first 100 rows
print(first_100_rows.to_string())
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children smoker     region    claim
# 0      0          1  39.0   male  23.2             91      Yes         0     No  southeast  1121.87
# 1      1          2  24.0   male  30.1             87       No         0     No  southeast  1131.51
# 2      2          3   NaN   male  33.3             82      Yes         0     No  southeast  1135.94
# 3      3          4   NaN   male  33.7             80       No         0     No  northwest  1136.40
# 4      4          5   NaN   male  34.1            100       No         0     No  northwest  1137.01
# 5      5          6   NaN   male  34.4             96      Yes         0     No  northwest  1137.47
# 6      6          7   NaN   male  37.3             86      Yes         0     No  northwest  1141.45
# 7      7          8  19.0   male  41.1            100       No         0     No  northwest  1146.80
# ...

# %%
df.fillna(method='pad')
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3  24.0    male  33.3             82      Yes         0
# 3         3          4  24.0    male  33.7             80       No         0
# 4         4          5  24.0    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df1=df['age'].fillna(value=50)

# %%
df1['age'] = df['age'].fillna(value=df['age'].mean())

# %%
df4=df.head(20)
df4
# Out:
#     index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0       0          1  39.0   male  23.2             91      Yes         0
# 1       1          2  24.0   male  30.1             87       No         0
# 2       2          3   NaN   male  33.3             82      Yes         0
# 3       3          4   NaN   male  33.7             80       No         0
# 4       4          5   NaN   male  34.1            100       No         0
# 5       5          6   NaN   male  34.4             96      Yes         0
# 6       6          7   NaN   male  37.3             86      Yes         0
# 7       7          8  19.0   male  41.1            100       No         0
# 8       8          9  20.0   male  43.0             86       No         0
# 9       9         10  30.0   male  53.1             97       No         0
# 10     10         11  36.0   male  19.8             88      Yes         0
# 11     11         12  37.0   male  20.3             90      Yes         0
# ...

# %%
df4.dropna(how='all')
#drop record if all coloumns in a row are empty(NaN)
# Out:
#     index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0       0          1  39.0   male  23.2             91      Yes         0
# 1       1          2  24.0   male  30.1             87       No         0
# 2       2          3   NaN   male  33.3             82      Yes         0
# 3       3          4   NaN   male  33.7             80       No         0
# 4       4          5   NaN   male  34.1            100       No         0
# 5       5          6   NaN   male  34.4             96      Yes         0
# 6       6          7   NaN   male  37.3             86      Yes         0
# 7       7          8  19.0   male  41.1            100       No         0
# 8       8          9  20.0   male  43.0             86       No         0
# 9       9         10  30.0   male  53.1             97       No         0
# 10     10         11  36.0   male  19.8             88      Yes         0
# 11     11         12  37.0   male  20.3             90      Yes         0
# ...

# %%
df4.dropna()
# Out:
#     index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0       0          1  39.0   male  23.2             91      Yes         0
# 1       1          2  24.0   male  30.1             87       No         0
# 7       7          8  19.0   male  41.1            100       No         0
# 8       8          9  20.0   male  43.0             86       No         0
# 9       9         10  30.0   male  53.1             97       No         0
# 10     10         11  36.0   male  19.8             88      Yes         0
# 11     11         12  37.0   male  20.3             90      Yes         0
# 12     12         13  19.0   male  20.7             81       No         0
# 16     16         17  35.0   male  34.1             90       No         0
# 17     17         18  41.0   male  34.4             84       No         0
# 18     18         19  49.0   male  35.4             97      Yes         0
# 19     19         20  48.0   male  33.3             91      Yes         0
#
# ...

# %%
df5=df.head(5)
df5['age'] = df5['age'].fillna(value=df5['age'].mean())
df5
# Out:
# <ipython-input-30-de57ab9bc3a2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['age'] = df5['age'].fillna(value=df5['age'].mean())
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3  31.5   male  33.3             82      Yes         0
# 3      3          4  31.5   male  33.7             80       No         0
# 4      4          5  31.5   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# ...

# %%
w = [23, 34, 43, 54, 45]
df5.loc[:, 'w'] = w

# %%
df5.loc[:, 'w'] = df5['w'] / df5['bmi']

# %%
df5
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3  31.5   male  33.3             82      Yes         0
# 3      3          4  31.5   male  33.7             80       No         0
# 4      4          5  31.5   male  34.1            100       No         0
#
#   smoker     region    claim         w
# 0     No  southeast  1121.87  0.042732
# 1     No  southeast  1131.51  0.037527
# 2     No  southeast  1135.94  0.038778
# 3     No  northwest  1136.40  0.047548
# 4     No  northwest  1137.01  0.038699
